# %% [markdown]
# #### Input & Output

# %%
name = "Sai"
print(f"My name is {name}.")
# Out:
# My name is Sai.

# %%
print("Name: \n", name)
# Out:
# Name:
#  Sai

# %%
name = input("Enter name:")
print(f'Name: {name}')
# Out:
# Name: Sai

# %%
age = int(input("Enter age:"))
print(f'Age: {age}')
# Out:
# Age: 22
