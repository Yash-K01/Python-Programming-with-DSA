# %% [markdown]
# #### Single Line and Multi Line

# %%
# This is a single-line comment

''' Multi Line comment '''
""" Jhon Deo """
# Out:
# ' Jhon Deo '

# %% [markdown]
# #### Sep & End Property

# %%
name = "Sai"
age = 22
salary = 10000

print(name, age, salary, sep = " - ")
print(name, end = "") # end with nothing
print(age,  end = '_') # end with space
print(salary, end = ".") # end with dot
# Out:
# Sai - 22 - 10000
# Sai22_10000.
